# %%
import pandas as pd
import numpy as np
import re
from pathlib import Path

# %%
# # merge seasonal data from each month

# path_data= Path.cwd().parent/'data/raw'
# years = ['2020','2021']
# months = ['09','11']
# # months = ['09','10','11','12','01','02','03','04','05','06','07']
# seasons = [years[0]+'_'+month for month in months[0:4]]+[years[1]+'_'+month for month in months[4:]]
# df = [pd.read_csv(path_data/f'performance_{date}.csv', low_memory=False) for date in seasons]

# seasons,type(df),len(df),type(df[0])
# Out:
# (['2020_09', '2020_11'], list, 2, pandas.core.frame.DataFrame)

# %%
# # merge data from each season

path_data= Path.cwd().parent/'data/raw'
# years = ['13','14','15','16','17','18','19','20','21']
years = ['16','17','18','19','20','21']
seasons = [ years[i]+years[i+1] for i in range(len(years)) if i <len(years)-1]
df = [pd.read_csv(path_data/f'merge_s{season}.csv', low_memory=False) for season in seasons]

# %%
df_concat = pd.concat(df,axis=0)

# %%
df_concat.shape
# Out:
# (3752, 19)

# %%
sum(i.shape[0] for i in df)
# Out:
# 3752

# %%
df_concat=df_concat.reset_index(drop=True)

# %%
df_concat.to_csv('all_season.csv',index=False)

# %%
df_csv= pd.read_csv('all_season.csv')

# %%
df_csv
# Out:
#      place  horse_no                   horse     jockey    trainer  \
# 0        1       5.0        JOY MASTER(B222)  J Moreira   C Fownes
# 1        2      11.0        ART OF RAW(V368)     H T Mo  C W Chang
# 2        3      10.0    THE FULL BLOOM(V243)  K C Leung    C H Yip
# 3        4       1.0       WHO'S HORSE(C233)   K Teetan   K H Ting
# 4        5       7.0  GREEN GENERATION(C355)     C Y Ho  C W Chang
# ...    ...       ...                     ...        ...        ...
# 3747    10      11.0            AI ONE(E139)  M L Yeung  D A Hayes
# 3748    11       3.0      RIGHT CHOICE(C013)   N Callan    F C Lor
# 3749    12      10.0   LEGION OF MERIT(D419)     C Y Ho   D J Hall
# 3750    13       8.0        HAPPY QIJI(D390)  T Piccone     W Y So
# 3751    14       7.0  INDIGENOUS REALM(D458)  K C Leung    P F Yiu
#
#       actual_weight declared_horse_weight draw     lbw  \
# 0               128                  1070    3       -
# 1               115                  1085    8     3/4
# 2               119                  1085    1   1-1/4
# 3               133                  1140    6   1-1/4
# 4               126                  1052    7   1-1/2
# ...             ...                   ...  ...     ...
# 3747            122                  1032    9   6-1/4
# 3748            129                  1082    1   7-1/2
# 3749            123                  1238    5   7-3/4
# 3750            123                  1013   11  10-1/4
# 3751            124                  1208    8  24-3/4
#
#                                        running_position finish_time win_odds  \
# 0     7                                             ...     1:35.89      2.6
# 1     2                                             ...     1:36.03       13
# 2     5                                             ...     1:36.07      7.3
# 3     1                                             ...     1:36.09      7.2
# 4     9                                             ...     1:36.13       36
# ...                                                 ...         ...      ...
# 3747  14                                            ...     1:22.87       74
# 3748  8                                             ...     1:23.07       13
# 3749  12                                            ...     1:23.08      106
# 3750  5                                             ...     1:23.51       21
# 3751  3                                             ...     1:25.80       31
#
#          race                      class going                 turf  \
# 0        1(1)   Class 5 - 1600M - (40-0)  GOOD    TURF - "A" Course
# 1        1(1)   Class 5 - 1600M - (40-0)  GOOD    TURF - "A" Course
# 2        1(1)   Class 5 - 1600M - (40-0)  GOOD    TURF - "A" Course
# 3        1(1)   Class 5 - 1600M - (40-0)  GOOD    TURF - "A" Course
# 4        1(1)   Class 5 - 1600M - (40-0)  GOOD    TURF - "A" Course
# ...       ...                        ...   ...                  ...
# 3747  11(305)  Class 3 - 1400M - (80-60)  GOOD  TURF - "A+3" Course
# 3748  11(305)  Class 3 - 1400M - (80-60)  GOOD  TURF - "A+3" Course
# 3749  11(305)  Class 3 - 1400M - (80-60)  GOOD  TURF - "A+3" Course
# 3750  11(305)  Class 3 - 1400M - (80-60)  GOOD  TURF - "A+3" Course
# 3751  11(305)  Class 3 - 1400M - (80-60)  GOOD  TURF - "A+3" Course
#
#               prize location        date
# 0       HK$ 750,000  Sha Tin   2020/09/6
# 1       HK$ 750,000  Sha Tin   2020/09/6
# 2       HK$ 750,000  Sha Tin   2020/09/6
# 3       HK$ 750,000  Sha Tin   2020/09/6
# 4       HK$ 750,000  Sha Tin   2020/09/6
# ...             ...      ...         ...
# 3747  HK$ 1,500,000  Sha Tin  2020/12/26
# 3748  HK$ 1,500,000  Sha Tin  2020/12/26
# 3749  HK$ 1,500,000  Sha Tin  2020/12/26
# 3750  HK$ 1,500,000  Sha Tin  2020/12/26
# 3751  HK$ 1,500,000  Sha Tin  2020/12/26
#
# [3752 rows x 19 columns]

# %%
df_csv.duplicated().any()
# Out:
# False
