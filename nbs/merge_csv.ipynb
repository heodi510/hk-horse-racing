# %%
import pandas as pd
import numpy as np
import re
from pathlib import Path

# %%
# merge seasonal data from each month

# path_data= Path.cwd().parent/'data/raw'
# years = ['2013','2014']
# months = ['09','10','11','12','01','02','03','04','05','06','07']
# seasons = [years[0]+'_'+month for month in months[0:4]]+[years[1]+'_'+month for month in months[4:]]
# df = [pd.read_csv(path_data/f'performance_{date}.csv', low_memory=False) for date in seasons]

# seasons,type(df),len(df),type(df[0])

# %%
# # merge data from each season

path_data= Path.cwd().parent/'data/raw'
years = ['13','14','15','16','17','18','19','20','21']
seasons = [ years[i]+years[i+1] for i in range(len(years)) if i <len(years)-1]
df = [pd.read_csv(path_data/f'merge_s{season}.csv', low_memory=False) for season in seasons]

# %%
df_concat = pd.concat(df,axis=0)

# %%
df_concat.shape
# Out:
# (71332, 19)

# %%
sum(i.shape[0] for i in df)
# Out:
# 71332

# %%
df_concat=df_concat.reset_index(drop=True)

# %%
df_concat.to_csv('all_season.csv',index=False)

# %%
df_csv= pd.read_csv('all_season.csv')

# %%
df_csv
# Out:
#       place  horse_no                   horse     jockey       trainer  \
# 0         1      10.0    AMAZING ALWAYS(N432)   K Teetan  D E Ferraris
# 1         2       9.0    FLYING SUPREME(K226)    W M Lai        T K Ng
# 2         3      11.0         COSMO ONE(M410)    D Whyte      Y S Tsui
# 3         4       6.0  SOUTHERN SPRINGS(P139)  K C Leung      C S Shum
# 4         5       5.0  BERNARD'S CHOICE(N156)   Z Purton  P O'Sullivan
# ...     ...       ...                     ...        ...           ...
# 71327     8       6.0     GENTLE BREEZE(B343)   K H Chan       P F Yiu
# 71328     9      10.0    ALLIED AGILITY(C314)    A Badel       P F Yiu
# 71329    10      12.0    SAUL'S SPECIAL(A293)   V Borges     C W Chang
# 71330    11       5.0      BEAUTY AMIGO(C124)  M L Yeung     D A Hayes
# 71331    12      11.0       MR LUMIERES(B179)     H T Mo      D J Hall
#
#        actual_weight declared_horse_weight draw    lbw  \
# 0                125                  1126    9      -
# 1                127                  1074   11    1/2
# 2                123                  1030   13  1-3/4
# 3                126                  1107   10  2-1/4
# 4                128                  1044    6  2-1/4
# ...              ...                   ...  ...    ...
# 71327            113                  1192   11  4-1/2
# 71328            118                  1150    1  4-1/2
# 71329            118                  1100    8  5-3/4
# 71330            121                  1108    4  7-1/4
# 71331            115                  1115    3  7-3/4
#
#                                         running_position finish_time win_odds  \
# 0      6                                             ...     1:10.37       26
# 1      4                                             ...     1:10.47       14
# 2      7                                             ...     1:10.66      4.5
# 3      2                                             ...     1:10.71       31
# 4      8                                             ...     1:10.72      4.3
# ...                                                  ...         ...      ...
# 71327  10                                            ...     0:57.41      109
# 71328  4                                             ...     0:57.42      7.4
# 71329  12                                            ...     0:57.62       28
# 71330  9                                             ...     0:57.87      122
# 71331  5                                             ...     0:57.95       48
#
#         race                       class going               turf  \
# 0       1(1)   Class 5 - 1200M - (40-15)  GOOD  TURF - "A" Course
# 1       1(1)   Class 5 - 1200M - (40-15)  GOOD  TURF - "A" Course
# 2       1(1)   Class 5 - 1200M - (40-15)  GOOD  TURF - "A" Course
# 3       1(1)   Class 5 - 1200M - (40-15)  GOOD  TURF - "A" Course
# 4       1(1)   Class 5 - 1200M - (40-15)  GOOD  TURF - "A" Course
# ...      ...                         ...   ...                ...
# 71327  8(92)  Class 2 - 1000M - (100-80)  GOOD  TURF - "A" Course
# 71328  8(92)  Class 2 - 1000M - (100-80)  GOOD  TURF - "A" Course
# 71329  8(92)  Class 2 - 1000M - (100-80)  GOOD  TURF - "A" Course
# 71330  8(92)  Class 2 - 1000M - (100-80)  GOOD  TURF - "A" Course
# 71331  8(92)  Class 2 - 1000M - (100-80)  GOOD  TURF - "A" Course
#
#                prize      location        date
# 0        HK$ 550,000       Sha Tin  2013/09/08
# 1        HK$ 550,000       Sha Tin  2013/09/08
# 2        HK$ 550,000       Sha Tin  2013/09/08
# 3        HK$ 550,000       Sha Tin  2013/09/08
# 4        HK$ 550,000       Sha Tin  2013/09/08
# ...              ...           ...         ...
# 71327  HK$ 2,200,000  Happy Valley   2020/10/7
# 71328  HK$ 2,200,000  Happy Valley   2020/10/7
# 71329  HK$ 2,200,000  Happy Valley   2020/10/7
# 71330  HK$ 2,200,000  Happy Valley   2020/10/7
# 71331  HK$ 2,200,000  Happy Valley   2020/10/7
#
# [71332 rows x 19 columns]

# %%
df_csv.duplicated().any()
# Out:
# False
